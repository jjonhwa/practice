# %% [markdown]
# # 완전 기초

# %% [markdown]
# ## Indexing

# %%
sample_list = [5,1,2,3,6,8,9]

# %%
'''
i번째 위치에 있는 데이터를 확인하고 싶을 때 Indexing을 한다라고 표현
실제로 코드상에서 구현은 다음과 같음
'''

sample_list[0]
# Out:
# 5

# %%
'''
데이터의 개수를 확인할 수 있는 함수 len()
'''

len(sample_list)
# Out:
# 7

# %%
'''
프로그램 언어는 0부터 시작이기 때문에 데이터의 개수가 7이면 마지막 숫자는 6
'''

sample_list[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-5bd1bdd1a022> in <cell line: 5>()
#       3 '''
#       4
# ----> 5 sample_list[7]
#
# IndexError: list index out of range

# %%
'''
위치를 조회할 땐 한개씩 안보고 여러개 조회가 가능
다음과 같은 코드로 수행하여 0,1,2번째 데이터를 한번에 조회할 수 있음
'''

sample_list[0:3]
# Out:
# [5, 1, 2]

# %%
'''
데이터의 개수를 파악하기 어렵거나 헷갈릴때, 뒤에서부터 조회가 가능함
'''

sample_list[-1]
# Out:
# 9

# %%
'''
물론, 똑같이 여러 데이터를 조회할 수 있음
'''

sample_list[-3:-1]
# Out:
# [6, 8]

# %%
'''
시작이나 끝을 지정해주지 않으면 시작점부터 끝까지 조회
'''

sample_list[-3:]
# Out:
# [6, 8, 9]

# %% [markdown]
# ## Other functions

# %%
'''
데이터 중 가장 큰 수, 가장 작은 수를 기본적으로 확인할 수 있음
'''

print(f"가장 큰 수는 : {max(sample_list)}")
print(f"가장 작은 수는 : {min(sample_list)}")
# Out:
# 가장 큰 수는 : 9
# 가장 작은 수는 : 1

# %%
'''
데이터를 크기에 따라 나열할 수 있음
'''

print(f"오름차순 : {sorted(sample_list)}")
print(f"내림차순 : {sorted(sample_list, reverse=True)}")
# Out:
# 오름차순 : [1, 2, 3, 5, 6, 8, 9]
# 내림차순 : [9, 8, 6, 5, 3, 2, 1]

# %%
'''
데이터를 다 더한 값을 나타낼 수 있음
'''

print(f"데이터의 합은 : {sum(sample_list)}")
# Out:
# 데이터의 합은 : 34

# %% [markdown]
# ## List convert

# %%
'''
리스트에 데이터를 추가하고 싶다!
다음과 같은 코드로 리스트의 "뒤에" 추가할 수 있음
'''

print(f"원래 데이터 리스트는 : {sample_list}")
copy_list = sample_list
copy_list.append(10)
print(f"10이 추가된 데이터 리스트는 : {copy_list}")
# Out:
# 원래 데이터 리스트는 : [1, 2, 3, 5, 6, 8, 9]
# 10이 추가된 데이터 리스트는 : [1, 2, 3, 5, 6, 8, 9, 10]

# %%
'''
리스트에 데이터를 추가하고 싶다!
다음과 같은 코드로 리스트의 "뒤에" 추가할 수 있음
'''

print(f"원래 데이터 리스트는 : {sample_list}")
copy_list = sample_list
copy_list.append(10)
print(f"10이 추가된 데이터 리스트는 : {copy_list}")

# %%
'''
앞에 추가하고 싶다!
'''

print(f"원래 데이터 리스트는 : {copy_list}")
copy_list.insert(0,0)
print(f"0이 추가된 데이터 리스트는 : {copy_list}")
# Out:
# 원래 데이터 리스트는 : [0, 1, 2, 3, 5, 6, 8, 9, 10]
# 0이 추가된 데이터 리스트는 : [0, 0, 1, 2, 3, 5, 6, 8, 9, 10]

# %%
'''
다시 빼고싶다!
'''

print(f"원래 데이터 리스트는 : {copy_list}")
copy_list.pop(0)
print(f"0이 추가된 데이터 리스트는 : {copy_list}")
# Out:
# 원래 데이터 리스트는 : [0, 1, 2, 3, 5, 6, 8, 9, 10]
# 0이 추가된 데이터 리스트는 : [1, 2, 3, 5, 6, 8, 9, 10]

# %% [markdown]
# # 특수한 계산기 만들기

# %%
"""
평균과 중간값을 구하는 계산기를 만들어보자!

get_mean은 평균을 구하려고 하는 function이고
get_median은 중간값을 구하는 function이다.

number_list는 랜덤으로 주어지는 list 형태의 데이터이며 0 ~ 100까지의 10개 데이터 리스트로 주어진다.

'완벽합니다~!'가 나올 때까지 풀어보자!

"""

def get_mean(number_list):
    return


def get_median(number_list):
    return

# %%
import unittest
import random
import numpy as np

class TestBasicMath(unittest.TestCase):
    def make_random_number(self):
        random_number_list = np.random.randint(1e2, size=10)
        return list(random_number_list)

    def test_get_mean(self):
        for _ in range(10):
            random_number_list = self.make_random_number()
            pred = get_mean(random_number_list)
            self.assertEqual(pred, np.mean(random_number_list))

    def test_get_median(self):
        for _ in range(10):
            random_number_list = self.make_random_number()
            pred = get_median(random_number_list)
            self.assertEqual(pred, np.median(random_number_list))

# %%
tbm = TestBasicMath()

tbm.test_get_mean()
tbm.test_get_median()

print("완벽합니다~!")
# Out:
# Congratulation!

# %%
"""
숫자가 리스트가 아닌 str타입으로 주어졌을 때, 각 자리의 숫자 합을 계산하는 계산기를 만들어보자!

예시) 643
= 6 + 4 + 3
= 13

function이름은 sum_digits로 만들어주세요!
"""
# Out:
# '\n숫자가 리스트가 아닌 str타입으로 주어졌을 때, 각 자리의 숫자 합을 계산하는 계산기를 만들어보자!\n\n예시) 643\n= 6 + 4 + 3\n= 13\n\nfunction이름은 sum_digits로 만들어주세요!\n'

# %%
import unittest
import random
import numpy as np

class TestBasicMath(unittest.TestCase):
    def make_random_number(self):
        random_number_str = np.random.randint(1e10)
        return str(random_number_str)

    def test_sum_digits(self):
        for _ in range(10):
            random_number_str = self.make_random_number()
            pred = sum_digits(random_number_str)
            self.assertEqual(pred, eval("+".join(x for x in str(random_number_str))))

    def test_get_median(self):
        for _ in range(10):
            random_number_list = self.make_random_number()
            pred = get_median(random_number_list)
            self.assertEqual(pred, np.median(random_number_list))

# %%
tbm = TestBasicMath()

tbm.test_sum_digits()

print("완벽합니다~!")
